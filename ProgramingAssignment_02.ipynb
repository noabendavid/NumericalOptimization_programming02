# %% [markdown]
# <center><h2><span style="color:darkblue">Numerical Optimization with Python</span></h2></center>
# <center><h3><span style="color:darkblue">Programming Assignment 02</span></h3></center>
# <center><p><strong>Noa Ben David, ID: 300950565</strong></p></center>

# %% [markdown]
# <p><strong>Git Source code:</strong><a href="https://github.com/noabendavid/NumericalOptimization_programming02"> https://github.com/noabendavid/NumericalOptimization_programming02</a></p>
#
# <h3><span style="color:darkgreen">Quadratic Function</span></h3>

# %%
import unittest
import numpy as np
from src.constrained_min import interior_pt 
from src.utils import * 
from ex2_tests.examples import *
from ex2_tests.test_constrained_min import *
 
main_run('QP', np.array([0.1, 0.2, 0.7]),qp_function,qp_eq_constraints,qp_ineq_constraints, plot_qp)
# Out:
# ********************
#  ***** QP *****
# ********************
# QP Optimal solution: [0.49968414 0.49968414 0.00063172]
# QP Optimal value: 1.5006323147997394
# QP Inequality Path history: [-0.49968414189915056, -0.49968414189915056, -0.0006317162016994576]
# QP Equality value: 1.0000000000000007

# %% [markdown]
# <h3><span style="color:darkgreen">Linear function</span></h3>

# %%
main_run('LP', np.array([0.5, 0.75]), lp_function, lp_eq_constraints, lp_ineq_constraints, plot_lp)
# Out:
# ********************
#  ***** LP *****
# ********************
# LP Optimal solution: [1.99362766 0.99362766]
# LP Optimal value: -2.9872553281085907
# LP Inequality Path history: [-1.9872553281085907, -0.0063723359463421225, -0.006372335945067142, -0.9936276640536579]
